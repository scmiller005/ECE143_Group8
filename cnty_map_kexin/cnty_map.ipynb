# %%
import folium
import branca.colormap as cm
import numpy as np
import pandas as pd

def generate_aadt_map_point(csv_file):
    """
    Generate a scatter map of AADT (Annual Average Daily Traffic) with colors varying by AADT value based on a CSV file.
    
    Parameters:
    - csv_file (str): Path to the CSV file, which must contain the columns "Latitude", "Longitude", and "VEHICLE_AADT_TOTAL".
    
    Returns:
    - folium.Map object
    """
    # 1. Read the CSV file
    df = pd.read_csv(csv_file)
    filtered_df = df[df["CNTY"].isin(["SD", "LA", "ORA"])].copy()

    # Calculate the difference in POSTMILE values
    filtered_df["POSTMILE_DIFF"] = filtered_df["POSTMILE"].diff()

    # Keep only rows where the difference is >= 2
    filtered_df = filtered_df[filtered_df["POSTMILE_DIFF"] >= 2]
    
    # 2. Create a Folium map (set the center to the mean of coordinates)
    m = folium.Map(
        location=[filtered_df["Latitude"].mean(), filtered_df["Longitude"].mean()], 
        zoom_start=7, 
        tiles="OpenStreetMap"
    )

    # 3. Create a color map (for the scatter plot with a gradient of AADT values)
    colormap = cm.LinearColormap(
        colors=["blue", "green", "yellow", "red"],  
        vmin=filtered_df["VEHICLE_AADT_TOTAL"].min(),  
        vmax=filtered_df["VEHICLE_AADT_TOTAL"].max()
    )

    # 4. Loop through the data and plot the scatter points
    for _, row in filtered_df.iterrows():
        lat, lon, aadt = row["Latitude"], row["Longitude"], row["VEHICLE_AADT_TOTAL"]
        color = colormap(aadt) # Calculate color based on AADT value

        folium.CircleMarker(
            location=(lat, lon),
            radius=4,  # Marker size
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.8,
            popup=folium.Popup(f"AADT: {aadt}", parse_html=True)  # Display AADT value on hover
        ).add_to(m)

    # 5. add legend to the map
    colormap.caption = "AADT traffic data"
    colormap.add_to(m)

    # 6. Return the map object
    return m

# %%
aadt_map = generate_aadt_map_point("D:/143/project/coordinates/i5_2022_coordinates.csv")  

display(aadt_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3055dd285e4b9c36cd23bc8dc9e245e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3055dd285e4b9c36cd23bc8dc9e245e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3055dd285e4b9c36cd23bc8dc9e245e = L.map(
#                 &quot;map_f3055dd285e4b9c36cd23bc8dc9e245e&quot;,
#                 {
#                     center: [33.67474904214559, -117.87542145593869],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f973869afa03a83bf350d190c56e2dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f973869afa03a83bf350d190c56e2dd.addTo(map_f3055dd285e4b9c36cd23bc8dc9e245e);
#
#
#             var circle_marker_a14a7b4929deb7161553c4eb5189a234 = L.circleMarker(
#                 [32.58383333333334, -117.08725],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#098500ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#098500ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f3055dd285e4b9c36cd23bc8dc9e245e);
#
#
#         var popup_682e8a1b32c3f8b2bf2245b52b9571bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94ad2c572e157d1d557ce61e02c29abe = $(`&lt;div id=&quot;html_94ad2c572e157d1d557ce61e02c29abe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AADT: 133000&lt;/div&gt;`)[0];
#                 popup_682e8a1b32c3f8b2bf2245b52b9571bd.setContent(html_94ad2c572e157d1d557ce61e02c29abe);
#
#
#
#         circle_marker_a14a7b4929deb7161553c4eb5189a234.bindPopup(popup_682e8a1b32c3f8b2bf2245b52b9571bd)
#         ;
#
#
#
#
#             var circle_marker_c665f48ce59801da56e1166dadfb14a4 = L.circleMarker(
#                 [32.67477777777778, -117.10988888888888],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f2f900ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f2f900ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f3055dd285e4b9c36cd23bc8dc9e245e);
#
#
#         var popup_2959df2589d5af13cfe9486231251706 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eff233f6c0cec29cd2c95f1b8444a32a = $(`&lt;div id=&quot;html_eff233f6c0cec29cd2c95f1b8444a32a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AADT: 197000&lt;/div&gt;`)[0];
#                 popup_2959df2589d5af13cfe9486231251706.setContent(html_eff233f6c0cec29cd2c95f1b8444a32a);
#
#
#
#         circle_marker_c665f48ce59801da56e1166dadfb14a4.bindPopup(popup_2959df2589d5af13cfe9486231251706)
#         ;
#
#
#
#
#             var circle_marker_6a17511474105eb3702924a2569d3ffd = L.circleMarker(
#                 [32.75911111111111, -117.20402777777778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#52a900ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#52a900ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f3055dd285e4b9c36cd23bc8dc9e245e);
#
#
#         var popup_9d7b45059663e0259c2fe2fbdaf5f7ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc626f6667f98846f16db7f690fb022b = $(`&lt;div id=&quot;html_fc626f6667f98846f16db7f690fb022b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AADT: 153000&lt;/div&gt;`)[0];
#                 popup_9d7b45059663e0259c2fe2fbdaf5f7ef.setContent(html_fc626f6667f98846f16db7f690fb022b);
#
#
#
#         circle_marker_6a17511474105eb3702924a2569d3ffd.bindPopup(popup_9d7b45059663e0259c2fe2fbdaf5f7ef)
#         ;
#
#
#
#
#             var circle_marker_7775e9e126b32fd130695d7568aeb6a7 = L.circleMarker(
#                 [32.80652777777777
